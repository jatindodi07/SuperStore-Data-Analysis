# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("SampleSuperstore.csv")

# %%
ds.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
ds.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
ds = ds.drop(columns=["Postal Code"], axis=1)

# %%
ds.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
ds["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
ds["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
ds["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
ds["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
ds.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %%
ds.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
ds.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
ds.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
ds.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
ds.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
ds.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
ds.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
ds.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <AxesSubplot:ylabel='Profit'>

# %%
ds.groupby("Sub-Category")["Sales"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
ds.groupby("Sub-Category")["Profit"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
ds.groupby("Segment")["Sales"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Segment'>

# %%
ds.groupby("Segment")["Profit"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Segment'>

# %%
ds.groupby("State")["Sales"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='State'>

# %%
ds.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='State'>

# %%
ds.groupby("Category")["Discount"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
ds.groupby("Sub-Category")["Discount"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
ds.groupby("Ship Mode")["Sales"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %%
ds.groupby("Ship Mode")["Profit"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11540\414940418.py in <module>
# ----> 1 ds.groupby("Category")["State"].sum().plot.bar()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1129         other axis represents a measured value.
#    1130         """
# -> 1131         return self(kind="bar", x=x, y=y, **kwargs)
#    1132
#    1133     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...
